# %%
list1 = ["Pakistan", 5, "Karachi"]

# %%
print(len(list1))
print(type(list1))
# Out:
# 3
# <class 'list'>

# %% [markdown]
# ### Nested List

# %%
list2 = ['Sameen','Zaki',['Yummy','Tummy']]
len(list2)
print(list2[-1][1])
# Out:
# Tummy

# %%
#List Concat
list1 = [1,2,3,4]
list3 = [5,6,7,8]
new_list = list1 + list3
print(new_list)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
new = [1,2]
newOne = new + [3,4]
print(newOne)
# Out:
# [1, 2, 3, 4]

# %%
#Membership in lists 
list = [1,2,3,4]
print(1 in list)
print(0 in list)
# Out:
# True
# False

# %% [markdown]
# ### Mutability

# %%
list1 = ["Maths", "Physics", "Chemistry", "Biology"]
list1[2] = "Data Science"
print(list1)
# Out:
# ['Maths', 'Physics', 'Data Science', 'Biology']

# %%
#extend() function --> It extends the list
list1 = [1,2,3,4]
list1.extend([5])
print(list1)
# Out:
# [1, 2, 3, 4, 5]

# %%
list1 = [1,2,3,4]
list1.append([5])
list1.append(6)
print(list1)
# Out:
# [1, 2, 3, 4, [5], 6]

# %%
#del command
list1 = [1,2,3,4]
del list1[1]
print(list1)
# Out:
# [1, 3, 4]

# %%
# Default --> Removes the last element

list1 = [11,22,33,44]
list1.pop()
print(list1)
list1.pop(2)
print(list1)
# Out:
# [11, 22, 33]
# [11, 22]

# %%
#remove() - takes value as an input
list1 = [1,2,3,4]
list1.remove(3)
print(list1)
# Out:
# [1, 2, 4]

# %%
#Sorting 
A = [9,5,2]
A.sort()
A
# Out:
# [2, 5, 9]

# %%
A.sort(reverse=True)
A
# Out:
# [9, 5, 2]

# %% [markdown]
# ### Difference between sort & sorted

# %%
A = ["Oranges", "Strawberry", "Mango"]
A.sort()
B = A.sort()
A
print(B)
# Out:
# None

# %%
A
# Out:
# ['Mango', 'Oranges', 'Strawberry']

# %%
A = ["Oranges", "Strawberry", "Mango"]
B = sorted(A)
print(B)
# Out:
# ['Mango', 'Oranges', 'Strawberry']

# %% [markdown]
# ### shallow copy

# %%
A = ["Oranges", "Strawberry", "Mango"]
B = A
print(A)
print(B)
# Out:
# ['Oranges', 'Strawberry', 'Mango']
# ['Oranges', 'Strawberry', 'Mango']

# %%
A.pop()
print(A)
print(B)
# Out:
# ['Oranges', 'Strawberry']
# ['Oranges', 'Strawberry']

# %%
A = ["Oranges", "Strawberry", "Mango"]
B = A[0:3]
A.pop()
print(B)
# Out:
# ['Oranges', 'Strawberry', 'Mango']

# %% [markdown]
# Description
# Split the string input_str = 'Kumar_Ravi_003' to the person's second name, first name and unique customer code. In this example, second_name= 'Kumar', first_name= 'Ravi', customer_code = '003'.
#
# A sample output of the input 'Kumar_Ravi_003' is:

# %%
input_str = 'Kumar_Ravi_003'
output = input_str.split('_')
print(output)
# Out:
# ['Kumar', 'Ravi', '003']

# %% [markdown]
# Question 3: I Lost Everything!
# word = ['1','2','3','4']
# word[ : ] = [ ]
# print(word)
# Sorted List
# Consider the following list:
# L = ['one','two','three', 'four', 'five', 'six']
# print(sorted(L))
# print (L)

# %%
L = ['one','two','three', 'four', 'five', 'six']
print(sorted(L))
print (L)
A = ['one','two','three', 'four', 'five', 'six']
A.sort()
print (A)
# Out:
# ['five', 'four', 'one', 'six', 'three', 'two']
# ['one', 'two', 'three', 'four', 'five', 'six']
# ['five', 'four', 'one', 'six', 'three', 'two']

# %% [markdown]
# Description
# Remove SPSS from input_list=['SAS', 'R', 'PYTHON', 'SPSS'] and add 'SPARK' in its place.
#
# Sample Input:
#
# ['SAS', 'R', 'PYTHON', 'SPSS']
#
# Sample Output:
#
# ['SAS', 'R', 'PYTHON', 'SPARK']

# %%
list = ['SAS', 'R', 'PYTHON', 'SPSS']
list[-1] = 'SPARK'
print(list)
# Out:
# ['SAS', 'R', 'PYTHON', 'SPARK']

# %% [markdown]
# Description
# Convert a list ['Pythons syntax is easy to learn', 'Pythons syntax is very clear'] to a string using ‘&’. The sample output of this string will be: Pythons syntax is easy to learn & Pythons syntax is very clear
#
# Note that there is a space on both sides of '&' (as usual in English sentences).

# %%
input_list = ['Pythons syntax is easy to learn', 'Pythons syntax is very clear']
string = str(input_list).lstrip("['").rstrip("']" "").replace("', '",' & ')
print(string)
# Out:
# Pythons syntax is easy to learn & Pythons syntax is very clear

# %% [markdown]
# How will I extract Python from the nested list
# input_list = [['SAS','R'],['Tableau','SQL'],['Python','Java']]

# %%
input_list = [['SAS','R'],['Tableau','SQL'],['Python','Java']]
output_word = input_list[-1][0]
print(output_word)
# Out:
# Python
