# %%
word = "Sameen Arsalan"
print(word)
print(type(word))
# Out:
# Sameen Arsalan
# <class 'str'>

# %%
len(word)
# Out:
# 14

# %%
word = "Sameen Arsalan"
word[0:6]
# Out:
# 'Sameen'

# %%
word[0:]
# Out:
# 'Sameen Arsalan'

# %%
word[:-1]
# Out:
# 'Sameen Arsala'

# %%
word[-1]
# Out:
# 'n'

# %%
word[-14:]
# Out:
# 'Sameen Arsalan'

# %%
word[-7:]
# Out:
# 'Arsalan'

# %%
newWord = word[0:] + " Khan"
print(newWord)
# Out:
# Sameen Arsalan Khan

# %% [markdown]
# ### Concat

# %%
name = "Sameen"
name2 = "Arsalan"
print(name + " " + name2)
# Out:
# Sameen Arsalan

# %%
word = "Best Of All Sameen"
word[0::2]
# Out:
# 'Bs fAlSme'

# %%
word1 = "Sameen is the best"
word1[::-1]
# Out:
# 'tseb eht si neemaS'

# %%
word2 = "Arsalan is the best"
word2[::-2]
# Out:
# 'te h inlsA'

# %% [markdown]
# ### String methods

# %%
text = "I love cats"
print(text.upper())
print(text.lower())
# Out:
# I LOVE CATS
# i love cats

# %%
text1 = "I love cats     "
text2 = "   I love cats"
text3 = "   I love cats    "
print(text1.rstrip())
print(text2.lstrip())
print(text3.strip())
print('i' in text1)
# Out:
# I love cats
# I love cats
# I love cats
# False

# %%
text = '***************4567890###############'
print(text.rstrip("#").lstrip("*"))
print(text.count('0'))
print(text.count("*",10))
print("*" in text)
print("1" in text)
# Out:
# 4567890
# 1
# 5
# True
# False

# %%
A = 'Data'
B = 'Scientist'
C = 'Python'
print('Hi, I am ' + '{0} {1} in {2}'.format(A,B,C))
# Out:
# Hi, I am Data Scientist in Python

# %% [markdown]
# ## Practice Question

# %% [markdown]
# Description
# In a certain encrypted message which has information about the location(area, city), the characters are jumbled such that first character of the first word is followed by the first character of the second word, then it is followed by second character of the first word and so on
#
# In other words, let’s say the location is bandra,mumbai
#
# The encrypted message says ‘bmaunmdbraai’.
#
# Sample Input:
# bmaunmdbraai
#
# Sample Output:
# bandra,mumbai
#
# Assume, both words are equal in length

# %%
encrypted_word = "bmaunmdbraai"
output_word1 = encrypted_word[0::2]
output_word2 = encrypted_word[1::2]
print(output_word1+","+output_word2)
# Out:
# bandra,mumbai
