# %% [markdown]
# ### Example of nested if-else

# %%
world_cups = {2019 : ['England', 'New-Zeland'], 2015:["Australia", "New Zeland"], 2011 : ["India", "Sri Lanka"], 2007: ["Australia", "Sri Lanka"], 2003: ["Australia", "India"]}

# %%
year = int(input("Which year worldcup Pakistan won?"))

if year in world_cups:
    if "Pakistan" in world_cups[year]:
        print("Pakistan won the world cup")
    else:
        print("Pakistan does not won the world cup")
else: 
    print("No world cup happen that year")
# Out:
# Which year worldcup Pakistan won? 2009
# No world cup happen that year

# %%
if True or True:
    if True and False or False:
        print("A")
    elif False and False or True and True:
        print("B")
    else:
        print("C")
else:
    print("C")
# Out:
# B

# %% [markdown]
# Description
# Write a code to check if the string in input_str starts with a vowel or not. Print capital YES or NO.
#
# For example, if input_str = 'analytics' then, your output should print 'YES'.
#
# Sample Input:
#
# alpha
#
# Sample Output:
#
# YES

# %%
input_str = 'analytics'

if input_str[0].lower() == 'a' or input_str[0].lower() == 'i' or input_str[0].lower() == 'e' or input_str[0].lower() == 'u' or input_str[0].lower() == 'o':
    print("vowels")
else:
    print("not a vowel")
# Out:
# vowels

# %%
input_str = 'hello analytics'
vowels = 'aeiou'

if input_str[0].lower() in vowels:
    print("vowels")
else:
    print("not a vowel")
# Out:
# not a vowel

# %%
input_str = 'hello analytics'

if input_str[0].lower() in ['a','e','i','o','u']:
    print("vowels")
else:
    print("not a vowel")
# Out:
# not a vowel

# %%
string = 'Chicken'

for ch in string:
    print(ch, end=":")
# Out:
# C:h:i:c:k:e:n:

# %%
students_data = {1:['Sameen', 24] , 2:['Laiba',25], 3:['Saina', 26], 4:['Saif',24], 5:['Rabeeca',27]}

for keys,values in students_data.items():
    print(keys,values)
# Out:
# 1 ['Sameen', 24]
# 2 ['Laiba', 25]
# 3 ['Saina', 26]
# 4 ['Saif', 24]
# 5 ['Rabeeca', 27]

# %% [markdown]
# ### Range function

# %%
for i in range(1,11,2):
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
for i in range(11,1,-2):
    print(i)
# Out:
# 11
# 9
# 7
# 5
# 3

# %%
ch = ""
while ch != 'quit':
   ch = input()
   print(ch)
# Out:
#  not quit
# not quit
#  quit
# quit

# %%
while True:
    ch = input()
    if ch=='quit':
        break
    print(ch)

# %%
x = 0
while x <= 20:
    x+=3
    if x % 5 == 0:
        continue
    print(x)
# Out:
# 3
# 6
# 9
# 12
# 18
# 21

# %% [markdown]
# Practice Questions
# Description
# You are given a list of string elements and asked to return a list which contains each element of the string in title case or in other words first character of the string would be in upper case and remaining all characters in lower case
#
# Sample Input: ['VARMA', 'raj', 'Gupta', 'SaNdeeP']
#
# Sample Output ['Varma', 'Raj', 'Gupta', 'Sandeep']

# %%
string_1 = "hello world"
string_1.title()
# Out:
# 'Hello World'

# %%
string_1.capitalize()
# Out:
# 'Hello world'

# %%
Sample_Input= ['VARMA', 'raj', 'Gupta', 'SaNdeeP']
new_list = [i.title() for i in Sample_Input]
new_list
# Out:
# ['Varma', 'Raj', 'Gupta', 'Sandeep']

# %%
l1 = ["automobiles", "Honda", "Benz", "Suzuki", "Morris Garages" ]

l2 = [len(i) for i in l1]
l2
# Out:
# [11, 5, 4, 6, 14]

# %%
l3 = [1,2,3,4,5]

# %%
for i,j,k in zip(l1,l2,l3):
        print(i, " - ", j, "Number is: ", k)
# Out:
# automobiles  -  11 Number is:  1
# Honda  -  5 Number is:  2
# Benz  -  4 Number is:  3
# Suzuki  -  6 Number is:  4
# Morris Garages  -  14 Number is:  5

# %%
n = int(input("Enter a number= "))
for n in range(1,n+1):
    print(n*n)
# Out:
# Enter a number=  5
# 1
# 4
# 9
# 16
# 25

# %%
input_list = (list(range(1,100)))
output_list = {}

for val in input_list:
    if val % 3 == 0:
        output_list[val] = val ** 3

# %%
output_list
# Out:
# {3: 27,
#  6: 216,
#  9: 729,
#  12: 1728,
#  15: 3375,
#  18: 5832,
#  21: 9261,
#  24: 13824,
#  27: 19683,
#  30: 27000,
#  33: 35937,
#  36: 46656,
#  39: 59319,
#  42: 74088,
#  45: 91125,
#  48: 110592,
#  51: 132651,
#  54: 157464,
#  57: 185193,
#  60: 216000,
#  63: 250047,
#  66: 287496,
#  69: 328509,
#  72: 373248,
#  75: 421875,
#  78: 474552,
#  81: 531441,
#  84: 592704,
#  87: 658503,
#  90: 729000,
#  93: 804357,
#  96: 884736,
#  99: 970299}

# %%
output_dict2 = {val: val**3 for val in input_list if val % 3 == 0}

# %%
output_dict2
# Out:
# {3: 27,
#  6: 216,
#  9: 729,
#  12: 1728,
#  15: 3375,
#  18: 5832,
#  21: 9261,
#  24: 13824,
#  27: 19683,
#  30: 27000,
#  33: 35937,
#  36: 46656,
#  39: 59319,
#  42: 74088,
#  45: 91125,
#  48: 110592,
#  51: 132651,
#  54: 157464,
#  57: 185193,
#  60: 216000,
#  63: 250047,
#  66: 287496,
#  69: 328509,
#  72: 373248,
#  75: 421875,
#  78: 474552,
#  81: 531441,
#  84: 592704,
#  87: 658503,
#  90: 729000,
#  93: 804357,
#  96: 884736,
#  99: 970299}

# %%
for i in "abc":
    for j in "def":
        print(i+j)
# Out:
# ad
# ae
# af
# bd
# be
# bf
# cd
# ce
# cf

# %%
alpha = [i+j for i in 'abc' for j in 'def']

# %%
alpha
# Out:
# ['ad', 'ae', 'af', 'bd', 'be', 'bf', 'cd', 'ce', 'cf']

# %%
d = {x.upper(): x*3 for x in 'abc'}
d
# Out:
# {'A': 'aaa', 'B': 'bbb', 'C': 'ccc'}

# %%
def func(*args):
    print(args)

func(1,2,"Sameen")
# Out:
# (1, 2, 'Sameen')

# %%
countries = ["India", "Japan", "Italy", "France"]

# %%
list(filter(lambda x: x.startswith('I'), countries))
# Out:
# ['India', 'Italy']

# %%
my_list = [3,4,5,6,7,8,9]

list(filter(lambda x: x % 3 == 0, my_list))
# Out:
# [3, 6, 9]

# %%
students_data = {1:['Sam', 15] , 2:['Zaki',18], 3:['Saina', 16], 4:['Saif',19], 5:['Sameen',20]}

len(list(filter(lambda x: x[1] > 18, students_data.values())))
# Out:
# 2
