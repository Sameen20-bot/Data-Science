# %%
list1 = [1,2,3,4,5,6,5,7,2,2,2,3]
s = set(list1)
s
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
A = {0,2,4,6,8}
B = {1,2,3,4,5}
print(A | B)
print(A.union(B))
# Out:
# {0, 1, 2, 3, 4, 5, 6, 8}
# {0, 1, 2, 3, 4, 5, 6, 8}

# %%
print(A & B)
print(A.intersection(B))
# Out:
# {2, 4}
# {2, 4}

# %%
print(A - B)
print(A.difference(B))
# Out:
# {0, 8, 6}
# {0, 8, 6}

# %%
print(A ^ B)
# Out:
# {0, 1, 3, 5, 6, 8}

# %%
d1 = {"Pakistan": "PKR", "USA": "USD", "Hong Kong": "HKD"}
d1
# Out:
# {'Pakistan': 'PKR', 'USA': 'USD', 'Hong Kong': 'HKD'}

# %%
del d1["USA"]

# %%
d1
# Out:
# {'Pakistan': 'PKR', 'Hong Kong': 'HKD'}

# %%
d1.get("Pakistan")
# Out:
# 'PKR'

# %%
d1.update({"Hong Kong": "HK"})
d1
# Out:
# {'Pakistan': 'PKR', 'Hong Kong': 'HK'}

# %%
Employee_data = {101:['Sameen',22,'Data Scientist'],102:['Daniya',23,'Java Developer'],103:['Naheen',26,'Content Writer']}
emp = Employee_data.get(101)
emp[2]
# Out:
# 'Data Scientist'

# %%
dict_1 = {"Python":40, "R":45}
del dict_1["R"]
dict_1
# Out:
# {'Python': 40}

# %%
inputs = {'Jack Dorsey' : 'Twitter' , 'Tim Cook' : 'Apple','Jeff Bezos' : 'Amazon' ,'Mukesh Ambani' : 'RJIO'}
output = sorted(inputs.values())
output
# Out:
# ['Amazon', 'Apple', 'RJIO', 'Twitter']
