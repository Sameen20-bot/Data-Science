# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
url = "https://raw.githubusercontent.com/jbrownlee/Datasets/refs/heads/master/airline-passengers.csv"
df = pd.read_csv(url)

# %%
df.head()
# Out:
#      Month  Passengers
# 0  1949-01         112
# 1  1949-02         118
# 2  1949-03         132
# 3  1949-04         129
# 4  1949-05         121

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Month       144 non-null    object
#  1   Passengers  144 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 2.4+ KB

# %% [markdown]
# # Perform Seasonal Decompose

# %%
result = seasonal_decompose(df['Passengers'], model='multiplicative', period=12)

# %%
fig = result.plot()
fig.set_size_inches(10, 10)
plt.show()

# %%
result2 = seasonal_decompose(df['Passengers'], model='additive', period=12)

# %%
fig2 = result2.plot()
fig2.set_size_inches(10, 10)
plt.show()

# %% [markdown]
# # Ab jesay kay trend kay sath seasonal graph dekho woh bar bar raha hain increase horha hain
# # multiplicative zada best option hain
