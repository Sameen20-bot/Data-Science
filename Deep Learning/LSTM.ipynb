# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout

# %%
df = pd.read_csv('NSE-TATAGLOBAL.csv')

# %%
train_set = df.iloc[:,1:2].values

# %%
df.head()
# Out:
#          Date    Open    High     Low    Last   Close  Total Trade Quantity  \
# 0  2018-09-28  234.05  235.95  230.20  233.50  233.75               3069914
# 1  2018-09-27  234.55  236.80  231.10  233.80  233.25               5082859
# 2  2018-09-26  240.00  240.00  232.50  235.00  234.25               2240909
# 3  2018-09-25  233.30  236.75  232.00  236.25  236.10               2349368
# 4  2018-09-24  233.55  239.20  230.75  234.00  233.30               3423509
#
#    Turnover (Lacs)
# 0          7162.35
# 1         11859.95
# 2          5248.60
# 3          5503.90
# 4          7999.55

# %%
train_set.shape
# Out:
# (2035, 1)

# %% [markdown]
# # Feature Scaling

# %%
mm = MinMaxScaler(feature_range = (0,1))
train_set_scaled = mm.fit_transform(train_set)

# %%
train_set_scaled.shape
# Out:
# (2035, 1)

# %% [markdown]
# # Creating a data structure with 60 timesteps(train) and 1 output(target)

# %%
X_train = []
Y_train = []
for i in range(60, 2035):
    X_train.append(train_set_scaled[i-60:i, 0])
    Y_train.append(train_set_scaled[i, 0])
    X_train, Y_train = np.array(X_train), np.array(Y_train)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 4
#       2 Y_train = []
#       3 for i in range(60, 2035):
# ----> 4     X_train.append(train_set_scaled[i-60:i, 0])
#       5     Y_train.append(train_set_scaled[i, 0])
#       6     X_train, Y_train = np.array(X_train), np.array(Y_train)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'append'

# %%
X_train.shape
# Out:
# (1, 60)
