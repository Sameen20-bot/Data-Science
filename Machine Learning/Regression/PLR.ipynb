# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

from sklearn.preprocessing import PolynomialFeatures, StandardScaler

from sklearn.metrics import r2_score

from sklearn.linear_model import LinearRegression

# %%
X = 6 * np.random.rand(200,1)-3
Y = 0.8*X**2 + 0.9*X + 2 + np.random.randn(200,1)

# %%
plt.plot(X,Y,".b")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %%
X
# Out:
# array([[-1.76053461e+00],
#        [-1.25309932e-01],
#        [-2.02245424e+00],
#        [-2.72499991e+00],
#        [ 1.16266147e+00],
#        [-2.20555191e+00],
#        [ 1.04336245e+00],
#        [-1.22248921e+00],
#        [-1.91221316e+00],
#        [-7.69922423e-01],
#        [-9.09092668e-01],
#        [-1.98560676e+00],
#        [-2.77673825e+00],
#        [ 2.26240368e-03],
#        [-1.53193599e+00],
#        [ 1.92934155e+00],
#        [-2.62010596e+00],
#        [-6.45135287e-01],
#        [-1.42341231e+00],
#        [-2.31792485e+00],
#        [-2.73370770e+00],
#        [ 1.25086472e+00],
#        [ 2.89783389e+00],
#        [ 2.19889831e+00],
#        [-1.80044303e+00],
#        [-1.68420065e+00],
#        [-2.68939786e+00],
#        [ 2.43115190e+00],
#        [-2.01842123e-01],
#        [ 2.47258789e-01],
#        [ 6.03108009e-01],
#        [ 2.60454564e+00],
#        [-1.54727490e+00],
#        [-2.56480321e+00],
#        [ 1.07690257e+00],
#        [ 6.26468485e-01],
#        [-2.11166924e+00],
#        [ 9.65132599e-01],
#        [ 7.87411240e-01],
#        [ 1.58019199e+00],
#        [ 2.65432119e-01],
#        [-2.60339970e+00],
#        [ 1.31819893e+00],
#        [-1.97409853e+00],
#        [ 1.44373908e+00],
#        [-7.93501642e-02],
#        [ 1.46242632e+00],
#        [ 7.70581056e-01],
#        [-7.50386289e-01],
#        [ 1.27316072e+00],
#        [-1.02550607e+00],
#        [ 1.51857172e+00],
#        [-1.51798180e+00],
#        [ 2.97464445e+00],
#        [-9.38720725e-02],
#        [ 2.09463529e+00],
#        [ 2.27195392e+00],
#        [ 2.53745618e+00],
#        [ 1.02330512e-01],
#        [-5.95919788e-01],
#        [-2.51351782e+00],
#        [-1.60492435e+00],
#        [-4.58022256e-01],
#        [ 2.22411395e+00],
#        [ 2.32502591e-01],
#        [ 4.84196792e-01],
#        [ 2.72832643e+00],
#        [-4.31740776e-01],
#        [ 1.16689124e+00],
#        [ 3.41974825e-01],
#        [ 2.43858088e-01],
#        [ 1.61606216e+00],
#        [-6.87078302e-01],
#        [ 1.71733920e+00],
#        [-2.72077364e+00],
#        [-2.15491245e+00],
#        [-1.49377085e+00],
#        [-4.54657336e-01],
#        [-4.69329030e-01],
#        [ 1.82747313e+00],
#        [-2.51216462e+00],
#        [-8.44342189e-01],
#        [-9.88475716e-01],
#        [-1.87897950e+00],
#        [ 5.99653604e-01],
#        [-9.29347789e-02],
#        [ 2.07696495e+00],
#        [-6.00733883e-01],
#        [ 2.78157344e+00],
#        [-6.61298496e-01],
#        [-1.07848704e+00],
#        [ 2.74914171e+00],
#        [-6.15287793e-01],
#        [-7.03299797e-01],
#        [-2.32694391e-01],
#        [ 3.94854346e-01],
#        [ 1.62814458e+00],
#        [ 7.46095906e-01],
#        [ 2.97095685e+00],
#        [ 2.36119180e+00],
#        [-1.85731816e+00],
#        [-1.67709437e+00],
#        [ 1.51442142e+00],
#        [ 1.35973711e+00],
#        [ 2.88037263e+00],
#        [ 5.96175857e-01],
#        [ 8.19918455e-01],
#        [-2.05311796e+00],
#        [ 4.92507993e-01],
#        [-2.38887568e+00],
#        [ 1.15132133e+00],
#        [ 1.21603755e+00],
#        [ 1.83005526e+00],
#        [ 2.91363979e+00],
#        [ 4.77792848e-01],
#        [ 1.97901843e+00],
#        [ 2.10976362e+00],
#        [ 1.98448881e-01],
#        [-2.72685273e+00],
#        [-1.77061800e+00],
#        [-3.99743962e-01],
#        [-2.39923922e-01],
#        [ 6.14043867e-01],
#        [-2.97347038e+00],
#        [ 2.96101374e-01],
#        [-2.19765426e+00],
#        [-1.77669632e+00],
#        [ 6.92595893e-01],
#        [-4.16339190e-01],
#        [-2.50720948e+00],
#        [ 2.34813676e+00],
#        [ 7.54807047e-01],
#        [ 1.20455877e-01],
#        [ 2.95612647e+00],
#        [ 1.73029310e-02],
#        [-2.66889356e+00],
#        [-2.63620102e+00],
#        [ 6.52589187e-01],
#        [-9.83559604e-01],
#        [ 2.99320303e+00],
#        [ 1.05681191e+00],
#        [ 1.19827796e+00],
#        [-1.36054732e+00],
#        [ 8.43683518e-01],
#        [-2.73803679e-01],
#        [ 6.26790010e-01],
#        [-1.44257138e+00],
#        [ 6.42123447e-01],
#        [-6.26615635e-01],
#        [-1.19816403e+00],
#        [-1.72200751e+00],
#        [ 5.87411440e-01],
#        [ 1.71163086e+00],
#        [ 8.60470602e-01],
#        [ 2.88772695e+00],
#        [ 5.42176290e-01],
#        [ 1.71166193e+00],
#        [ 1.94395742e+00],
#        [ 7.02362087e-01],
#        [ 1.35305091e+00],
#        [-2.29013675e+00],
#        [ 1.29894158e+00],
#        [-1.80152155e+00],
#        [ 1.07601625e+00],
#        [-2.41268813e+00],
#        [-2.74358201e+00],
#        [-8.38281401e-01],
#        [ 3.01578895e-01],
#        [-1.96004635e+00],
#        [ 9.54860553e-01],
#        [-9.65487368e-01],
#        [ 7.43311058e-01],
#        [-2.19314834e+00],
#        [-3.20539343e-01],
#        [-7.13378144e-01],
#        [ 2.23435180e+00],
#        [ 4.99281193e-02],
#        [ 2.50527995e+00],
#        [ 1.12699713e+00],
#        [ 1.31584226e-01],
#        [ 1.59251197e+00],
#        [ 3.99320947e-01],
#        [ 4.06020182e-01],
#        [-6.63694744e-01],
#        [ 5.99044747e-01],
#        [ 2.40055414e+00],
#        [-2.81923028e+00],
#        [ 2.51422557e+00],
#        [ 2.56464055e+00],
#        [ 2.36649818e+00],
#        [-1.03394617e+00],
#        [-1.18327338e+00],
#        [-3.14733573e-01],
#        [-1.44318618e+00],
#        [ 1.67036422e+00],
#        [-1.54765890e+00],
#        [-2.24704512e+00],
#        [-1.59255323e+00],
#        [-1.99581472e+00],
#        [-3.15602907e-01]])

# %%
Y
# Out:
# array([[ 3.15189117],
#        [ 1.76948577],
#        [ 3.44763093],
#        [ 5.18476599],
#        [ 3.69343599],
#        [ 4.33302225],
#        [ 2.44559853],
#        [ 2.71607323],
#        [ 3.66256409],
#        [ 3.75344895],
#        [ 2.24691477],
#        [ 3.18748684],
#        [ 5.66656725],
#        [ 3.67259769],
#        [ 2.43968395],
#        [ 7.14397225],
#        [ 3.84532097],
#        [ 1.27615152],
#        [ 3.11132117],
#        [ 4.59757876],
#        [ 5.81918395],
#        [ 4.67426903],
#        [11.15691882],
#        [ 5.16409354],
#        [ 3.93216292],
#        [ 2.89647751],
#        [ 4.00890591],
#        [11.23259803],
#        [ 1.28465209],
#        [ 1.63782017],
#        [ 2.84510241],
#        [ 9.57600029],
#        [ 2.06020584],
#        [ 4.3181589 ],
#        [ 2.84945695],
#        [ 2.53252812],
#        [ 4.63571825],
#        [ 4.55583207],
#        [ 3.73409786],
#        [ 5.44264704],
#        [ 1.64714056],
#        [ 6.53597983],
#        [ 5.45889433],
#        [ 4.63861214],
#        [ 5.34027634],
#        [ 1.89661346],
#        [ 4.89039483],
#        [ 3.76593296],
#        [ 0.69708756],
#        [ 4.22394767],
#        [ 1.49089721],
#        [ 7.74515077],
#        [ 2.05980979],
#        [10.4100825 ],
#        [ 1.57993427],
#        [ 6.41841506],
#        [ 8.24828485],
#        [ 9.30891108],
#        [ 3.66855321],
#        [-0.89883313],
#        [ 4.11892552],
#        [ 3.09236368],
#        [ 1.22757553],
#        [ 7.09077249],
#        [ 1.2800598 ],
#        [ 3.09995312],
#        [11.15714849],
#        [ 0.94702393],
#        [ 4.50451986],
#        [ 2.962702  ],
#        [ 2.32706788],
#        [ 5.15701483],
#        [ 2.44276564],
#        [ 4.8284338 ],
#        [ 6.49270483],
#        [ 2.73002632],
#        [ 1.50933968],
#        [ 1.37020889],
#        [-0.04665513],
#        [ 8.11096945],
#        [ 5.40159773],
#        [ 2.91963787],
#        [ 1.0883094 ],
#        [ 2.39576551],
#        [ 1.67698126],
#        [ 1.86536048],
#        [ 7.50570864],
#        [ 0.28513039],
#        [ 9.00530165],
#        [ 2.02802709],
#        [ 0.91299507],
#        [11.42716336],
#        [ 1.78093774],
#        [ 2.15990722],
#        [ 2.43152743],
#        [ 2.29502545],
#        [ 4.87432149],
#        [ 2.75463833],
#        [11.57455716],
#        [ 8.01833784],
#        [ 3.50190222],
#        [ 1.92786003],
#        [ 5.32589765],
#        [ 5.86012531],
#        [11.72067094],
#        [ 4.60829995],
#        [ 3.15718531],
#        [ 4.1709085 ],
#        [ 2.33027716],
#        [ 5.03260373],
#        [ 2.66847862],
#        [ 4.07205832],
#        [ 5.4798873 ],
#        [12.02231823],
#        [ 1.82526482],
#        [ 6.37185131],
#        [ 7.19483691],
#        [ 2.27778778],
#        [ 6.50893575],
#        [ 3.08932442],
#        [ 3.15714831],
#        [ 0.86839976],
#        [ 1.21179021],
#        [ 4.81945982],
#        [ 4.34281928],
#        [ 4.06443992],
#        [ 2.29105758],
#        [ 0.76203335],
#        [ 3.27240354],
#        [ 5.12457743],
#        [ 8.78314509],
#        [ 2.41499232],
#        [ 2.16080731],
#        [12.88526541],
#        [ 2.10206651],
#        [ 4.69543358],
#        [ 4.55547492],
#        [ 3.86971212],
#        [ 2.99780287],
#        [12.47315981],
#        [ 4.18591233],
#        [ 3.31805526],
#        [ 2.01001021],
#        [ 2.95114766],
#        [ 1.73164   ],
#        [ 2.18524126],
#        [ 2.69553427],
#        [ 3.97416593],
#        [ 0.59052685],
#        [ 2.31152903],
#        [ 2.42190454],
#        [ 2.14407568],
#        [ 5.95399166],
#        [ 2.15802827],
#        [10.81274954],
#        [ 2.82884872],
#        [ 3.84285976],
#        [ 5.83989048],
#        [ 2.5373966 ],
#        [ 4.02498427],
#        [ 4.29736798],
#        [ 5.93083493],
#        [ 1.91190001],
#        [ 2.39519225],
#        [ 5.31658706],
#        [ 5.76635254],
#        [ 0.94818455],
#        [ 0.60952331],
#        [ 5.68600381],
#        [ 3.40815517],
#        [ 1.34234885],
#        [ 3.63170986],
#        [ 4.40158898],
#        [ 1.51435768],
#        [ 1.76865916],
#        [ 6.5577115 ],
#        [-0.03421911],
#        [ 9.85043736],
#        [ 3.17974573],
#        [ 2.52776595],
#        [ 5.26092218],
#        [ 0.43657523],
#        [ 2.03612268],
#        [ 2.44621237],
#        [ 2.30823284],
#        [ 9.23265167],
#        [ 6.13300259],
#        [10.09612278],
#        [ 9.96579994],
#        [ 8.21601861],
#        [ 2.96895665],
#        [ 3.14301361],
#        [ 1.27226378],
#        [ 2.00776995],
#        [ 4.36065755],
#        [ 2.25705966],
#        [ 4.06937105],
#        [ 3.59872787],
#        [ 2.32895336],
#        [ 1.81374284]])

# %% [markdown]
# # Train Test Split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state = 42)

# %%
len(X_train)
# Out:
# 160

# %%
len(X_test)
# Out:
# 40

# %% [markdown]
# # Feature Scaling

# %%
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
X_train
# Out:
# array([[ 1.07860274],
#        [-0.98633344],
#        [ 0.45063641],
#        [-1.1118527 ],
#        [ 0.34596103],
#        [-0.95922724],
#        [ 0.12450432],
#        [-1.42429676],
#        [ 0.48461236],
#        [ 1.22924038],
#        [ 0.26369568],
#        [-0.21831962],
#        [-1.35644847],
#        [-1.09751496],
#        [ 0.09503398],
#        [ 1.01210632],
#        [ 0.61329457],
#        [ 1.76901289],
#        [-1.34895947],
#        [ 0.95825258],
#        [ 0.55173859],
#        [ 0.42569112],
#        [ 1.54778192],
#        [-1.70131814],
#        [ 0.35346274],
#        [-1.093845  ],
#        [ 0.77111426],
#        [ 1.40405413],
#        [-0.67595166],
#        [-1.61646487],
#        [ 0.89209491],
#        [ 0.393389  ],
#        [-1.11250389],
#        [-1.59666015],
#        [-1.67119836],
#        [ 1.73440613],
#        [-1.64858394],
#        [ 1.78244465],
#        [-1.14619264],
#        [ 0.70943148],
#        [-1.24589815],
#        [-0.2992971 ],
#        [ 0.85819557],
#        [ 1.49324867],
#        [-0.73921933],
#        [-0.08089703],
#        [ 0.7594871 ],
#        [-1.29976419],
#        [-0.64905886],
#        [-0.99380285],
#        [ 1.72486287],
#        [ 0.69870864],
#        [-1.03737751],
#        [-1.57335645],
#        [-1.22365046],
#        [ 0.98374387],
#        [ 0.79215712],
#        [ 0.60517408],
#        [ 1.44309062],
#        [-0.26614162],
#        [ 0.67720418],
#        [-0.95899539],
#        [-0.84625341],
#        [ 0.35365687],
#        [-1.4671353 ],
#        [-0.19010166],
#        [-0.57367509],
#        [-0.30132876],
#        [ 1.08016178],
#        [-0.89577772],
#        [-0.53092081],
#        [-1.08775688],
#        [-1.2298138 ],
#        [ 0.49474803],
#        [ 0.12245105],
#        [-1.82010064],
#        [ 0.11559485],
#        [ 0.84691262],
#        [ 0.62488972],
#        [-0.14665287],
#        [ 0.13547697],
#        [ 0.27258036],
#        [ 0.30256897],
#        [ 1.00867851],
#        [-1.04166812],
#        [ 1.30286104],
#        [ 0.33690489],
#        [ 0.36291486],
#        [-0.53458018],
#        [ 0.92929987],
#        [-1.20821765],
#        [ 0.44047471],
#        [-0.16528078],
#        [ 1.71876053],
#        [-1.21670204],
#        [-0.61863657],
#        [-1.67007967],
#        [ 0.33517272],
#        [ 1.77123939],
#        [ 1.76005864],
#        [ 0.9367384 ],
#        [ 0.65567085],
#        [ 1.42461637],
#        [ 0.74392119],
#        [-1.54157444],
#        [ 0.62542486],
#        [-0.76289698],
#        [ 0.67035726],
#        [ 1.63508582],
#        [-1.15927128],
#        [ 0.00536043],
#        [ 0.21631608],
#        [-0.42406245],
#        [-1.17933703],
#        [-0.02341907],
#        [-0.38458824],
#        [ 0.42400969],
#        [ 0.43095072],
#        [-0.41430346],
#        [-0.43962773],
#        [ 1.32426708],
#        [-0.01433794],
#        [ 0.1573016 ],
#        [-0.42550925],
#        [ 1.31808569],
#        [-0.08146294],
#        [-1.26441223],
#        [-0.64396292],
#        [-1.38150115],
#        [ 0.03699983],
#        [-0.47785169],
#        [ 1.65466739],
#        [ 0.73045936],
#        [ 1.50727479],
#        [-1.40751892],
#        [-0.21481423],
#        [-1.53858263],
#        [ 0.55794063],
#        [ 1.14893338],
#        [-0.89614893],
#        [-0.10044443],
#        [-0.94130886],
#        [-0.74820998],
#        [ 1.39296792],
#        [ 0.32988096],
#        [ 0.79619409],
#        [ 1.40085026],
#        [ 1.24904349],
#        [-0.38749488],
#        [-1.66752794],
#        [-0.16964581],
#        [-0.21533911],
#        [-1.67533724],
#        [ 1.52368811],
#        [ 0.95095748],
#        [ 0.47026354],
#        [-0.94973409],
#        [-0.39628221],
#        [ 0.05466258],
#        [ 0.88958906]])

# %%
X_test
# Out:
# array([[ 0.21361925],
#        [ 1.14010864],
#        [ 0.3393582 ],
#        [ 0.39928561],
#        [-0.27616145],
#        [ 1.17010244],
#        [ 0.18169176],
#        [-0.60772496],
#        [-0.45550699],
#        [-0.07269494],
#        [ 1.62251802],
#        [ 0.22036093],
#        [-1.68129913],
#        [-0.30815554],
#        [-1.72697388],
#        [ 1.4878475 ],
#        [ 1.3469704 ],
#        [ 1.00865975],
#        [-0.62160481],
#        [ 0.67975803],
#        [ 0.15399439],
#        [-1.60674702],
#        [-0.40312171],
#        [-0.44942191],
#        [ 0.26756224],
#        [-1.54239147],
#        [ 0.3372725 ],
#        [-0.28546058],
#        [-1.35168004],
#        [ 0.04794353],
#        [-0.48964717],
#        [-0.8842099 ],
#        [ 1.23990934],
#        [-1.32587349],
#        [-1.06449507],
#        [ 1.71432015],
#        [-1.6362039 ],
#        [ 0.36923384],
#        [-1.48151273],
#        [-0.92669083]])

# %% [markdown]
# # Linear Regression Model

# %%
lr = LinearRegression()
lr.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # Predictions

# %%
y_pred = lr.predict(X_test)
y_pred
# Out:
# array([[4.44141013],
#        [5.77493089],
#        [4.62238954],
#        [4.70864465],
#        [3.73645579],
#        [5.81810176],
#        [4.39545606],
#        [3.25922763],
#        [3.47831899],
#        [4.02931053],
#        [6.4692755 ],
#        [4.45111362],
#        [1.71400385],
#        [3.69040584],
#        [1.64826298],
#        [6.27544064],
#        [6.07267251],
#        [5.58573301],
#        [3.23924999],
#        [5.11233604],
#        [4.35559049],
#        [1.82130868],
#        [3.55371852],
#        [3.48707741],
#        [4.51905171],
#        [1.91393734],
#        [4.61938754],
#        [3.72307129],
#        [2.18843335],
#        [4.20294867],
#        [3.42918012],
#        [2.86127553],
#        [5.91857668],
#        [2.22557741],
#        [2.6017863 ],
#        [6.60140874],
#        [1.77891062],
#        [4.66539034],
#        [2.00156172],
#        [2.8001316 ]])

# %%
r2_score_lr = r2_score(Y_test, y_pred)
print(r2_score_lr)
# Out:
# 0.24773433511157006

# %%
plt.plot(X_train, lr.predict(X_train), color = "red")
plt.plot(X,Y, ".b")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %% [markdown]
# # Fix It By Applying Polynomial Regression

# %%
poly = PolynomialFeatures(degree = 2, include_bias = True)
X_train_poly = poly.fit_transform(X_train)
X_test_poly = poly.transform(X_test)

# %%
print(X_train[0])
# Out:
# [1.07860274]

# %%
print(X_train_poly[0])
# Out:
# [1.         1.07860274 1.16338388]

# %%
lr2 = LinearRegression()
lr2.fit(X_train_poly, Y_train)
# Out:
# LinearRegression()

# %%
y_pred2 = lr2.predict(X_test_poly)

# %%
r2_score(Y_test,y_pred2)
# Out:
# 0.8933165687672141

# %%
print(lr2.coef_)
# Out:
# [[0.         1.48170654 2.30567457]]

# %%
print(lr2.intercept_)
# Out:
# [1.82826771]
