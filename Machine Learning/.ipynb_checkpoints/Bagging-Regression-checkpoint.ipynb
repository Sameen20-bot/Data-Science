# %%
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

from sklearn.datasets import make_classification

from sklearn.preprocessing import StandardScaler

from sklearn.metrics import accuracy_score

from sklearn.ensemble import BaggingClassifier, RandomForestClassifier

from sklearn.tree import DecisionTreeClassifier

from sklearn.svm import SVC

# %%
### n_informative make_classification() mein batata hai ke total features mein se kitne 
### features actually target (y) ko predict karne ke liye useful/informative hain.

# %%
X, Y =  make_classification(n_samples = 10000, n_features = 10, n_informative = 3)

# %% [markdown]
# # Splitting the data into training & test

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state = 42)

# %%
len(X_train)
# Out:
# 8000

# %%
len(X_test)
# Out:
# 2000

# %% [markdown]
# # Feature Scaling

# %%
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
X_train
# Out:
# array([[-1.17362097,  0.54509924,  1.57183892, ..., -1.36074057,
#          1.17464315,  1.3197106 ],
#        [ 0.34082238,  0.77424556, -0.78463087, ...,  0.1693517 ,
#          0.97646679,  0.47495193],
#        [ 0.6749546 ,  3.12404962, -0.81150569, ..., -0.05867846,
#          1.87870808,  2.52166649],
#        ...,
#        [ 0.47190478,  0.67956187, -0.54192443, ...,  0.39066287,
#         -1.6727382 ,  0.29454866],
#        [ 0.57139233, -0.541718  , -2.72452759, ..., -1.18712684,
#         -0.9608856 , -0.94458387],
#        [-0.26555197, -0.88875108, -0.02493548, ...,  1.02403019,
#         -1.93745447, -0.65285751]], shape=(8000, 10))

# %%
X_test
# Out:
# array([[-0.67847847,  0.86694107, -0.41404485, ..., -0.82079709,
#          0.14816473,  1.27629064],
#        [-0.01757847,  0.09654833, -0.00677099, ..., -1.06451728,
#         -0.73080922,  0.14757739],
#        [-0.91975871, -1.04422389, -1.62596087, ..., -0.54269726,
#         -1.08492669, -0.34946201],
#        ...,
#        [ 0.81750274, -0.55169854,  0.38394852, ...,  0.69599095,
#          1.07667955, -1.01316577],
#        [ 0.82397853,  1.77662332,  1.09705998, ...,  1.26433639,
#          0.98748912,  1.10433016],
#        [ 1.63854918,  0.17694942, -0.94099078, ..., -0.64690468,
#         -0.7925603 , -0.93724367]], shape=(2000, 10))

# %% [markdown]
# # Decision Tree

# %%
dt = DecisionTreeClassifier()
dt.fit(X_train,Y_train)
pred = dt.predict(X_test)
print(accuracy_score(pred,Y_test)*100)
# Out:
# 91.5

# %% [markdown]
# # Bag Classifier

# %%
bag = BaggingClassifier(estimator = DecisionTreeClassifier(),
                        n_estimators = 500,
                        max_samples = 0.5,
                        bootstrap = True,
                        random_state = 42)

# %%
bag.fit(X_train, Y_train)
# Out:
# BaggingClassifier(estimator=DecisionTreeClassifier(), max_samples=0.5,
#                   n_estimators=500, random_state=42)

# %%
y_pred_bag = bag.predict(X_test)

# %%
print(accuracy_score(y_pred_bag,Y_test)*100)
# Out:
# 95.25

# %% [markdown]
# # Random Forest Classifier

# %%
rf = RandomForestClassifier(n_estimators = 500, random_state = 42) 
rf.fit(X_train,Y_train)
predrf = rf.predict(X_test)
print(accuracy_score(predrf,Y_test)*100)
# Out:
# 95.75

# %% [markdown]
# # Bagging Using SVM

# %%
bagSVM = BaggingClassifier(estimator = SVC(),
                        n_estimators = 500,
                        max_samples = 0.25,
                        bootstrap = True,
                        random_state = 42)

# %%
bagSVM.fit(X_train, Y_train)
# Out:
# BaggingClassifier(estimator=SVC(), max_samples=0.25, n_estimators=500,
#                   random_state=42)

# %%
y_pred_bagSVM = bagSVM.predict(X_test)

# %%
print(accuracy_score(y_pred_bagSVM,Y_test)*100)
# Out:
# 91.45
